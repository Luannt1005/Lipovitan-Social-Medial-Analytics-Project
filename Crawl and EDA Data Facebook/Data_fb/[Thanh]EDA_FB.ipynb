# %% [markdown]
# # I. Import Dataset

# %%
# Colab connect drive

from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# Load the data
post_info = pd.read_csv('/content/gdrive/Shareddrives/PRO PLAYER/1. HKII [2023-2024]/4. [Cube] A Sử/2. Cuối Kỳ/Data_fb/post_info.csv')
comment_fb = pd.read_csv('/content/gdrive/Shareddrives/PRO PLAYER/1. HKII [2023-2024]/4. [Cube] A Sử/2. Cuối Kỳ/Data_fb/comments.csv')

df_p = post_info.copy()
df_c = comment_fb.copy()
# Display the first few rows to understand its structure and contents
df_p.head(), df_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Time         77 non-null     object
#  1   Content      77 non-null     object
#  2   Like Num     77 non-null     object
#  3   Comment Num  77 non-null     object
#  4   Share Num    77 non-null     object
#  5   URL          77 non-null     object
# dtypes: object(6)
# memory usage: 3.7+ KB
# (                Time                                            Content  \
#  0  12 March at 19:00   LIPOVITAN TONGKAT ALI – NƯỚC TĂNG LỰC MẬT NHÂ...
#  1         9 February   TẾT RỒNG PHÚC QUÝ – NĂNG LƯỢNG NHƯ Ý \nKhoảnh...
#  2         5 February   CHUYẾN XE NĂNG LƯỢNG 0 ĐỒNG CÙNG BÀ CON VỀ QU...
#  3         25 January  LIPOVITAN x HONDA BIKER RALLY: SỰ KIỆN BÙNG NỔ...
#  4          9 January   CÔNG BỐ DANH SÁCH HƠN 600 KHÁCH HÀNG NHẬN ĐƯỢ...
#
#    Like Num  Comment Num  Share Num  \
# ...

# %%
df_p.head(50)
# Out:
#                  Time                                            Content  \
# 0   12 March at 19:00   LIPOVITAN TONGKAT ALI – NƯỚC TĂNG LỰC MẬT NHÂ...
# 1          9 February   TẾT RỒNG PHÚC QUÝ – NĂNG LƯỢNG NHƯ Ý \nKhoảnh...
# 2          5 February   CHUYẾN XE NĂNG LƯỢNG 0 ĐỒNG CÙNG BÀ CON VỀ QU...
# 3          25 January  LIPOVITAN x HONDA BIKER RALLY: SỰ KIỆN BÙNG NỔ...
# 4           9 January   CÔNG BỐ DANH SÁCH HƠN 600 KHÁCH HÀNG NHẬN ĐƯỢ...
# 5    31 December 2023  THÔNG BÁO: ĐÓNG LINK ĐĂNG KÝ CHUYẾN XE NĂNG LƯ...
# 6    25 December 2023  Tết đến nơi rồi, ôi dzồi ôi các anh mình ơi!!!...
# 7    25 December 2023   Loa loa loa…16 chiếc xe Năng lượng đã chuẩn b...
# 8    25 December 2023  Sắp gục ngã vì còn hàng ngàn đơn hàng Tết mà c...
# 9    13 December 2023   Tết Rồng Phú Quý – Năng Lượng Như Ý \n Tết đế...
# 10   11 December 2023   Hành Trình Chuyến Xe Năng Lượng 0 Đồng – Tết ...
# 11    8 December 2023   Tết Rồng Phúc Quý – Năng Lượng Như Ý \n  Tết ...
# ...

# %%
df_c.head(), df_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Comment  1405 non-null   object
#  1   Link     1436 non-null   object
# dtypes: object(2)
# memory usage: 22.6+ KB
# (                                             Comment  \
#  0                                       Nguyễn Hương
#  1                                       Revu Vietnam
#  2                                  Top fan\nTrần Nam
#  3                                        Nguyễn Hiền
#  4  Thanh Lê\nQuá tuyệt vời, vừa chất lượng vừa đẹ...
#
#                                                  Link
#  0  https://www.facebook.com/Lipovitan.vn/posts/pf...
#  1  https://www.facebook.com/Lipovitan.vn/posts/pf...
#  2  https://www.facebook.com/Lipovitan.vn/posts/pf...
#  3  https://www.facebook.com/Lipovitan.vn/posts/pf...
#  4  https://www.facebook.com/Lipovitan.vn/posts/pf...  ,
#  None)

# %% [markdown]
# # II. EDA POST DATASET

# %% [markdown]
# ## 2.0 Prepocessing

# %%
# Convert "Like Num" to numeric values, handling "K" as thousand
def convert_likes(likes):
    if 'K' in likes:
        # Remove the "K" and convert to float, then multiply by 1000
        return float(likes.replace('K', '')) * 1000
    else:
        return float(likes)

df_p['Like Num'] = df_p['Like Num'].apply(convert_likes)

# Display the updated dataframe to verify the changes
df_p.head(50)
# Out:
#                  Time                                            Content  \
# 0   12 March at 19:00   LIPOVITAN TONGKAT ALI – NƯỚC TĂNG LỰC MẬT NHÂ...
# 1          9 February   TẾT RỒNG PHÚC QUÝ – NĂNG LƯỢNG NHƯ Ý \nKhoảnh...
# 2          5 February   CHUYẾN XE NĂNG LƯỢNG 0 ĐỒNG CÙNG BÀ CON VỀ QU...
# 3          25 January  LIPOVITAN x HONDA BIKER RALLY: SỰ KIỆN BÙNG NỔ...
# 4           9 January   CÔNG BỐ DANH SÁCH HƠN 600 KHÁCH HÀNG NHẬN ĐƯỢ...
# 5    31 December 2023  THÔNG BÁO: ĐÓNG LINK ĐĂNG KÝ CHUYẾN XE NĂNG LƯ...
# 6    25 December 2023  Tết đến nơi rồi, ôi dzồi ôi các anh mình ơi!!!...
# 7    25 December 2023   Loa loa loa…16 chiếc xe Năng lượng đã chuẩn b...
# 8    25 December 2023  Sắp gục ngã vì còn hàng ngàn đơn hàng Tết mà c...
# 9    13 December 2023   Tết Rồng Phú Quý – Năng Lượng Như Ý \n Tết đế...
# 10   11 December 2023   Hành Trình Chuyến Xe Năng Lượng 0 Đồng – Tết ...
# 11    8 December 2023   Tết Rồng Phúc Quý – Năng Lượng Như Ý \n  Tết ...
# ...

# %%
# Extract only numeric part from "Comment Num" and "Share Num"
df_p['Comment Num'] = df_p['Comment Num'].str.extract('(\d+)').astype(float)
df_p['Share Num'] = df_p['Share Num'].str.extract('(\d+)').astype(float)

# Display the updated dataframe to verify the changes
df_p.head()
# Out:
#                 Time                                            Content  \
# 0  12 March at 19:00   LIPOVITAN TONGKAT ALI – NƯỚC TĂNG LỰC MẬT NHÂ...
# 1         9 February   TẾT RỒNG PHÚC QUÝ – NĂNG LƯỢNG NHƯ Ý \nKhoảnh...
# 2         5 February   CHUYẾN XE NĂNG LƯỢNG 0 ĐỒNG CÙNG BÀ CON VỀ QU...
# 3         25 January  LIPOVITAN x HONDA BIKER RALLY: SỰ KIỆN BÙNG NỔ...
# 4          9 January   CÔNG BỐ DANH SÁCH HƠN 600 KHÁCH HÀNG NHẬN ĐƯỢ...
#
#    Like Num  Comment Num  Share Num  \
# 0     109.0         14.0       33.0
# 1      53.0          1.0        3.0
# 2     148.0         35.0       38.0
# 3      84.0         22.0       14.0
# 4     130.0         46.0       18.0
#
#                                                  URL
# 0  https://www.facebook.com/Lipovitan.vn/posts/pf...
# 1  https://www.facebook.com/Lipovitan.vn/posts/pf...
# 2  https://www.facebook.com/Lipovitan.vn/posts/pf...
# 3  https://www.facebook.com/Lipovitan.vn/posts/pf...
# ...

# %%
# Process the "Time" column as specified
# Remove "19:00" from the first row and append "2024" to all rows
df_p.loc[0, 'Time'] = df_p.loc[0, 'Time'].replace(' at 19:00', '')
df_p.loc[:4,'Time'] = df_p.loc[:4,'Time'].apply(lambda x: x + ' 2024' if '2024' not in x else x)

# Map of month names to their numerical equivalents
month_to_num = {
    'January': '01',
    'February': '02',
    'March': '03',
    'April': '04',
    'May': '05',
    'June': '06',
    'July': '07',
    'August': '08',
    'September': '09',
    'October': '10',
    'November': '11',
    'December': '12'
}

# Function to replace month names with their numerical equivalents
def month_name_to_num(date_str):
    for month_name, month_num in month_to_num.items():
        if month_name in date_str:
            return date_str.replace(month_name, month_num)
    return date_str

df_p['Time'] = df_p['Time'].apply(month_name_to_num)

# %%
# Convert 'Time' column to datetime format
df_p['Time'] = pd.to_datetime(df_p['Time'], format='%d %m %Y')

# Sort DataFrame by 'Time'
df_p.sort_values(by='Time', inplace=True)

# Reset index if needed
df_p.reset_index(drop=True, inplace=True)

# %%
df_p.head(50)
# Out:
#          Time                                            Content  Like Num  \
# 0  2022-08-08  MỚI -  NƯỚC TĂNG LỰC ĐẦU TIÊN CÓ CHIẾT XUẤT CÂ...      23.0
# 1  2022-08-08   SINH LỰC DỒI DÀO – CHINH PHỤC ĐỈNH CAO\nSau n...     502.0
# 2  2022-08-08   NẮNG CHÓI CHANG – TONGKAT ALI SẴN SÀNG\nVào n...      25.0
# 3  2022-08-16   Món Quà Từ “1 Lon Nước Nhỏ - 1 Cộng Đồng To”\...      31.0
# 4  2022-08-22  Một Sự Đóng Góp Bằng Vạn Điều Sẻ Chia\nĐi học ...      69.0
# 5  2022-08-22   Món Quà Từ “1 Lon Nước Nhỏ - 1 Cộng Đồng To”\...     175.0
# 6  2022-08-22   Tạo Năng Lượng – Tiếp Sức Đến Trường\n Với ni...      91.0
# 7  2022-08-22   Hành Trình Trao Giấc Mơ Đến Trường\nChương tr...      30.0
# 8  2022-09-06   Tongkat Ali Và Những Công Dụng Bạn Không Thể ...      12.0
# 9  2022-09-06   Bạn Có Biết Đến Loại Nước Tăng Lực làm từ mật...      23.0
# 10 2022-09-06   Thương Hiệu Nhật – Chất Lượng Thật\nLipovitan...     174.0
# ...

# %% [markdown]
# ## 2.1 Temporal Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style of seaborn
sns.set(style="whitegrid")

# Ensure the data is sorted by Time
data_sorted = df_p.sort_values('Time')

# Plotting the engagement over time
plt.figure(figsize=(14, 8))

# Plot likes
plt.plot(data_sorted['Time'], data_sorted['Like Num'], label='Likes', marker='o', linestyle='-', markersize=5)
# Plot comments
plt.plot(data_sorted['Time'], data_sorted['Comment Num'], label='Comments', marker='x', linestyle='-', markersize=5)
# Plot shares
plt.plot(data_sorted['Time'], data_sorted['Share Num'], label='Shares', marker='s', linestyle='-', markersize=5)

plt.title('Engagement Over Time')
plt.xlabel('Time')
plt.ylabel('Engagement Counts')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# **The plot shows the trends of likes, comments, and shares over time across the dataset. Here are a few observations you might make:**
# - Trends and Patterns: Look for any clear trends, such as periods of increased engagement or notable spikes.
# - Seasonality: Determine if there's any seasonal pattern, like more engagement during specific months or times of the year.
# - Comparing Metrics: Assess how the different types of engagement (likes, comments, shares) correlate with each other over time.

# %%
# Extract the day of the week from 'Time' column (Monday=0, Sunday=6)
data_sorted['Day of Week'] = data_sorted['Time'].dt.dayofweek

# Aggregate likes, comments, and shares by day of the week
engagement_by_day = data_sorted.groupby('Day of Week')[['Like Num', 'Comment Num', 'Share Num']].mean()

# Plotting
plt.figure(figsize=(10, 6))
engagement_by_day.plot(kind='bar', ax=plt.gca())
plt.title('Average Engagement by Day of the Week')
plt.xlabel('Day of the Week (0=Monday, 6=Sunday)')
plt.ylabel('Average Engagement')
plt.xticks(rotation=0)
plt.legend(['Likes', 'Comments', 'Shares'])
plt.tight_layout()

plt.show()

# %% [markdown]
# ## 2.2 **Content Analysis**
# - **Text Length vs. Engagement**: Investigate if the length of the post content correlates with engagement metrics. Sometimes, shorter or longer posts perform differently.
# - **Keyword Analysis**: Identify frequently occurring words or phrases within your posts. This could help in understanding the topics that drive engagement.
# - **Sentiment Analysis**: Analyzing the sentiment of the post content and correlating it with engagement metrics might reveal if positive, negative, or neutral tones affect user interactions.

# %% [markdown]
# 1. Text Length vs. Engagement:
# - You can calculate the length of each post's content and then correlate it with engagement metrics such as Like Num, Comment Num, and Share Num. This can be done as follows:

# %%
# Calculate text length
df_p['Content Length'] = df_p['Content'].apply(len)

# Correlate text length with engagement metrics
engagement_metrics = ['Like Num', 'Comment Num', 'Share Num']
for metric in engagement_metrics:
    correlation = df_p['Content Length'].corr(df_p[metric])
    print(f"Correlation between Text Length and {metric}: {correlation}")
# Out:
# Correlation between Text Length and Like Num: -0.2014142175257614
# Correlation between Text Length and Comment Num: 0.3062023382794732
# Correlation between Text Length and Share Num: 0.433543663817023

# %%
# Calculate the average length of comments
average_comment_length = df_p['Content Length'].mean()

# Plot the distribution of comment lengths
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df_p['Content Length'], bins=50, kde=True)
plt.title('Distribution of Comment Lengths')
plt.xlabel('Comment Length')
plt.ylabel('Frequency')
plt.axvline(average_comment_length, color='r', linestyle='--', label=f'Average Length: {average_comment_length:.2f}')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Create scatter plots
plt.figure(figsize=(12, 4))
for i, metric in enumerate(engagement_metrics, 1):
    plt.subplot(1, 3, i)
    plt.scatter(df_p['Content Length'], df_p[metric], alpha=0.5)
    plt.title(f'{metric} vs. Content Length')
    plt.xlabel('Content Length')
    plt.ylabel(metric)
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
from collections import Counter
import re

# Tokenize and count word frequency
words = re.findall(r'\w+', ' '.join(df_p['Content']).lower())
word_freq = Counter(words)

# Print top 10 most common words
print("Top 10 most common words:")
for word, freq in word_freq.most_common(10):
    print(f"{word}: {freq}")
# Out:
# Top 10 most common words:
# lipovitan: 368
# lượng: 103
# để: 99
# năng: 95
# https: 85
# vn: 83
# 1: 82
# com: 71
# www: 70
# và: 69

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer
from torch.nn.functional import softmax
import torch

# Khởi tạo tokenizer và mô hình PhoBERT
tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base")
model = AutoModelForSequenceClassification.from_pretrained("vinai/phobert-base", num_labels=3)

# Hàm phân tích cảm xúc cho mỗi bình luận
def analyze_sentiment(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=256)
    with torch.no_grad():  # Không cần tính gradient
        outputs = model(**inputs)
    probs = softmax(outputs.logits, dim=1)
    sentiment = torch.argmax(probs, dim=1).numpy()[0]
    sentiment_mapping = {0: "Tiêu cực", 1: "Trung tính", 2: "Tích cực"}
    return sentiment_mapping[sentiment]

# Áp dụng hàm phân tích cảm xúc lên cột bình luận
df_p['sentiment'] = df_p['Content'].apply(analyze_sentiment)
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at vinai/phobert-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.countplot(x='sentiment', data=df_p, order = df_p['sentiment'].value_counts().index)
plt.title('Phân Phối Cảm Xúc')
plt.xlabel('Cảm Xúc')
plt.ylabel('Số Lượng')
plt.xticks(rotation=45)
plt.show()

# %%
df_p.head()
# Out:
#         Time                                            Content  Like Num  \
# 0 2022-08-08  MỚI -  NƯỚC TĂNG LỰC ĐẦU TIÊN CÓ CHIẾT XUẤT CÂ...      23.0
# 1 2022-08-08   SINH LỰC DỒI DÀO – CHINH PHỤC ĐỈNH CAO\nSau n...     502.0
# 2 2022-08-08   NẮNG CHÓI CHANG – TONGKAT ALI SẴN SÀNG\nVào n...      25.0
# 3 2022-08-16   Món Quà Từ “1 Lon Nước Nhỏ - 1 Cộng Đồng To”\...      31.0
# 4 2022-08-22  Một Sự Đóng Góp Bằng Vạn Điều Sẻ Chia\nĐi học ...      69.0
#
#    Comment Num  Share Num                                                URL  \
# 0          6.0        4.0  https://www.facebook.com/Lipovitan.vn/posts/pf...
# 1         38.0       17.0  https://www.facebook.com/Lipovitan.vn/posts/pf...
# 2         13.0       13.0  https://www.facebook.com/Lipovitan.vn/posts/pf...
# 3          2.0        7.0  https://www.facebook.com/Lipovitan.vn/posts/pf...
# 4          4.0        2.0  https://www.facebook.com/Lipovitan.vn/posts/pf...
#
#    Content Length sentiment
# 0             718  Tích cực
# ...

# %% [markdown]
# ## 2.3 Engagement Analysis

# %%
import matplotlib.pyplot as plt

# Vẽ biểu đồ line plot cho Like Num, Comment Num, Share Num, và Text Length
plt.figure(figsize=(10, 6))
plt.plot(df_p['Time'], df_p['Like Num'], marker='o', linestyle='-', label='Like Num')
plt.plot(df_p['Time'], df_p['Comment Num'], marker='o', linestyle='-', label='Comment Num')
plt.plot(df_p['Time'], df_p['Share Num'], marker='o', linestyle='-', label='Share Num')
plt.plot(df_p['Time'], df_p['Content Length'], marker='o', linestyle='-', label='Text Length')

# Đặt tiêu đề và nhãn cho biểu đồ
plt.title('Engagement Metrics over Time')
plt.xlabel('Time')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend()

plt.show()

# %%
# Calculate the percentage change in 'Like Num' between consecutive days
df_p['Like Num Change'] = df_p['Like Num'].pct_change() * 100

# Sort and filter days with a high percentage increase in likes
spike_threshold = df_p['Like Num Change'].mean() + df_p['Like Num Change'].std() * 2  # Using mean + 2*std as threshold for spikes
spike_days = df_p[df_p['Like Num Change'] > spike_threshold]

# Display the days with spike and associated content
spike_days[['Time', 'Like Num', 'Like Num Change', 'Content']]
# Out:
#          Time  Like Num  Like Num Change  \
# 1  2022-08-08     502.0      2082.608696
# 28 2022-12-01    1200.0      2005.263158
# 41 2023-03-30    1300.0      1784.057971
# 47 2023-04-26    1400.0      1650.000000
# 53 2023-08-22    2400.0      1986.956522
# 65 2023-12-08    6100.0      3270.165746
#
#                                               Content
# 1    SINH LỰC DỒI DÀO – CHINH PHỤC ĐỈNH CAO\nSau n...
# 28  Lipovitan – Lúa Trổ Bạt Ngàn – Tết Tràn Năng L...
# 41   Lipovitan | Bật Nắp Trúng Vàng 2023 \nChương ...
# 47   Bật Tongkat Ali – Trúng Ngay Lon Honey \nNếu ...
# 53  “Anh là dân thường, không phải dân chơi \nNhưn...
# 65   Tết Rồng Phúc Quý – Năng Lượng Như Ý \n  Tết ...

# %%
spike_days[['Time', 'Like Num', 'Like Num Change', 'Content']].sort_values('Time', ascending=False)
# Out:
#          Time  Like Num  Like Num Change  \
# 65 2023-12-08    6100.0      3270.165746
# 53 2023-08-22    2400.0      1986.956522
# 47 2023-04-26    1400.0      1650.000000
# 41 2023-03-30    1300.0      1784.057971
# 28 2022-12-01    1200.0      2005.263158
# 1  2022-08-08     502.0      2082.608696
#
#                                               Content
# 65   Tết Rồng Phúc Quý – Năng Lượng Như Ý \n  Tết ...
# 53  “Anh là dân thường, không phải dân chơi \nNhưn...
# 47   Bật Tongkat Ali – Trúng Ngay Lon Honey \nNếu ...
# 41   Lipovitan | Bật Nắp Trúng Vàng 2023 \nChương ...
# 28  Lipovitan – Lúa Trổ Bạt Ngàn – Tết Tràn Năng L...
# 1    SINH LỰC DỒI DÀO – CHINH PHỤC ĐỈNH CAO\nSau n...

# %% [markdown]
# ## 2.4 Anomaly Detection

# %%
import numpy as np

# Tính toán Z-score cho cột "Like Num"
mean_likes = np.mean(df_p['Like Num'])
std_dev_likes = np.std(df_p['Like Num'])
z_scores = [(x - mean_likes) / std_dev_likes for x in df_p['Like Num']]

# Xác định ngưỡng Z-score để xác định outliers (ví dụ: Z-score > 3 hoặc Z-score < -3)
threshold = 3
outliers = df_p[np.abs(z_scores) > threshold]

print("Outliers in 'Like Num':")
print(outliers[['Time', 'Content', 'Like Num']])
# Out:
# Outliers in 'Like Num':
#          Time                                            Content  Like Num
# 65 2023-12-08   Tết Rồng Phúc Quý – Năng Lượng Như Ý \n  Tết ...    6100.0
# 67 2023-12-13   Tết Rồng Phú Quý – Năng Lượng Như Ý \n Tết đế...    9100.0

# %% [markdown]
# ## 2.5 Frequency Analysis

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
import matplotlib.pyplot as plt

# Đảm bảo rằng bạn đã tải xuống bộ dữ liệu stopwords
nltk.download('punkt')
nltk.download('stopwords')

# Kết hợp tất cả các bình luận thành một chuỗi lớn
text = " ".join(comment for comment in df_p['Content'])

# Tokenize văn bản
tokens = word_tokenize(text)

# Chuyển tất cả các từ về dạng chữ thường để đồng nhất
words = [word.lower() for word in tokens if word.isalpha()]

# Lọc bỏ stopwords (bạn cần điều chỉnh cho phù hợp với tiếng Việt)
stop_words = set(stopwords.words('english')) # Sử dụng 'vietnamese' nếu có
words = [word for word in words if word not in stop_words]

# Tính toán tần suất xuất hiện của từ
fdist = FreqDist(words)

# In 10 từ xuất hiện nhiều nhất
print(fdist.most_common(10))

# Vẽ biểu đồ tần suất của 30 từ xuất hiện nhiều nhất
fdist.plot(30, cumulative=False)
plt.show()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [('lipovitan', 273), ('lượng', 103), ('để', 99), ('năng', 95), ('https', 85), ('và', 69), ('hãy', 67), ('tin', 66), ('thêm', 64), ('hệ', 64)]

# %%
from wordcloud import WordCloud

# Tạo đám mây từ
wordcloud = WordCloud(width = 800, height = 400, background_color ='white').generate(text)

# Hiển thị đám mây từ
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # III. EDA COMMENT DATASET

# %% [markdown]
# ## 3.0 Preprocessing

# %%
# Check for null values and duplicated rows
null_values = df_c.isnull().sum()
duplicated_rows = df_c.duplicated().sum()

null_values, duplicated_rows
# Out:
# (Comment    31
#  Link        0
#  dtype: int64,
#  46)

# %%
# Remove duplicated rows
df_c = df_c.drop_duplicates()

# Check the shape of the dataframe after removing duplicates
shape_after_deduplication = df_c.shape

shape_after_deduplication
# Out:
# (1390, 2)

# %%
# Check for null values and duplicated rows
null_values = df_c.isnull().sum()
duplicated_rows = df_c.duplicated().sum()

null_values, duplicated_rows
# Out:
# (Comment    2
#  Link       0
#  dtype: int64,
#  0)

# %% [markdown]
# - 2 videos have no comment

# %%
# Remove rows with null values in the 'Comment' column
df_c = df_c.dropna(subset=['Comment'])

# Check the shape of the dataframe after removing null values
shape_after_null_removal = df_c.shape

shape_after_null_removal
# Out:
# (1388, 2)

# %%
# Check for null values and duplicated rows
null_values = df_c.isnull().sum()
duplicated_rows = df_c.duplicated().sum()

null_values, duplicated_rows
# Out:
# (Comment    0
#  Link       0
#  dtype: int64,
#  0)

# %% [markdown]
# ## 3.1 Comment Length Analysis

# %%
# Calculate the length of each comment
df_c['Comment_Length'] = df_c['Comment'].apply(len)

# Calculate the average length of comments
average_comment_length = df_c['Comment_Length'].mean()

# Plot the distribution of comment lengths
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df_c['Comment_Length'], bins=50, kde=True)
plt.title('Distribution of Comment Lengths')
plt.xlabel('Comment Length')
plt.ylabel('Frequency')
plt.axvline(average_comment_length, color='r', linestyle='--', label=f'Average Length: {average_comment_length:.2f}')
plt.legend()
plt.show()

# %%
# Calculate the length of each comment in 'df_c'
df_c['Comment Length'] = df_c['Comment'].apply(len)

# Find the index of the post with the longest comment
max_comment_length_index = df_c['Comment Length'].idxmax()

# Access the corresponding post
post_with_max_comment_length = df_c.loc[max_comment_length_index, 'Comment'] # Replace 'Content' with 'Comment'

# Print the post with the longest comment
print(post_with_max_comment_length)
# Out:
# Author
# Nước Tăng Lực Lipovitan
# Bác Thành Chào bạn, bạn có thể mua Lipovitan tại các hệ thống siêu thị như Coopmart, Big C, Go, Satra, các cửa hàng tiện lợi như Cirle K, Family Mart,...hoặc tại các cửa hàng tạp hóa ạ. Ngoài ra, bạn có thể mua trực tiếp tại link Tiki này nhé: https://… See more

# %%
# Replace 'Comment Length' with the correct column name
median_comment_length = data_sorted['correct_column_name'].median()
median_comments = data_sorted[data_sorted['correct_column_name'] == median_comment_length]
median_comments
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'correct_column_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ## 3.2 Sentiment Analysis

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer
from torch.nn.functional import softmax
import torch

# Khởi tạo tokenizer và mô hình PhoBERT
tokenizer = AutoTokenizer.from_pretrained("vinai/phobert-base")
model = AutoModelForSequenceClassification.from_pretrained("vinai/phobert-base", num_labels=3)

# Hàm phân tích cảm xúc cho mỗi bình luận
def analyze_sentiment(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=256)
    with torch.no_grad():  # Không cần tính gradient
        outputs = model(**inputs)
    probs = softmax(outputs.logits, dim=1)
    sentiment = torch.argmax(probs, dim=1).numpy()[0]
    sentiment_mapping = {0: "Tiêu cực", 1: "Trung tính", 2: "Tích cực"}
    return sentiment_mapping[sentiment]

# Áp dụng hàm phân tích cảm xúc lên cột bình luận
# Thay 'cột_bình_luận' bằng tên thực tế của cột chứa bình luận trong DataFrame của bạn
df_c['sentiment'] = df_c['Comment'].apply(analyze_sentiment)

# %%
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.countplot(x='sentiment', data=df_c, order = df_c['sentiment'].value_counts().index)
plt.title('Phân Phối Cảm Xúc')
plt.xlabel('Cảm Xúc')
plt.ylabel('Số Lượng')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 3.3 Frequency Analysis

# %%
df_c.info()

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
import matplotlib.pyplot as plt

# Đảm bảo rằng bạn đã tải xuống bộ dữ liệu stopwords
nltk.download('punkt')
nltk.download('stopwords')

# Kết hợp tất cả các bình luận thành một chuỗi lớn
text = " ".join(comment for comment in df_c['Comment'])

# Tokenize văn bản
tokens = word_tokenize(text)

# Chuyển tất cả các từ về dạng chữ thường để đồng nhất
words = [word.lower() for word in tokens if word.isalpha()]

# Lọc bỏ stopwords (bạn cần điều chỉnh cho phù hợp với tiếng Việt)
stop_words = set(stopwords.words('english')) # Sử dụng 'vietnamese' nếu có
words = [word for word in words if word not in stop_words]

# Tính toán tần suất xuất hiện của từ
fdist = FreqDist(words)

# In 10 từ xuất hiện nhiều nhất
print(fdist.most_common(10))

# Vẽ biểu đồ tần suất của 30 từ xuất hiện nhiều nhất
fdist.plot(30, cumulative=False)
plt.show()

# %%
from wordcloud import WordCloud

# Tạo đám mây từ
wordcloud = WordCloud(width = 800, height = 400, background_color ='white').generate(text)

# Hiển thị đám mây từ
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## 3.4. Link Analysis

# %%
import pandas as pd
import re

# Hàm để tìm kiếm và trả về tất cả URLs trong một chuỗi văn bản
def extract_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.findall(text)

# Áp dụng hàm trên cho mỗi bình luận và tạo một list chứa tất cả URLs
all_urls = []
df_c['Comment'].apply(lambda x: all_urls.extend(extract_urls(x)))

# Bạn cũng có thể muốn lọc bỏ các phần mở rộng tệp tin để chỉ tập trung vào các liên kết cơ bản

# %%
from collections import Counter

# Tính toán tần suất xuất hiện của mỗi URL
url_counts = Counter(all_urls)

# Lấy ra 10 URLs xuất hiện nhiều nhất
most_common_urls = url_counts.most_common(10)
most_common_urls

# %% [markdown]
# ## 3.5 Engagement Metrics
# - Comments per Post: Calculate the average number of comments per post or video to gauge engagement levels.
# - Engagement Trends: Identify which types of content (based on the link or content description) generate more engagement.

# %%
# Tính Số Bình Luận Mỗi Bài Đăng
comments_per_post = df_c.groupby('Link').size()

# Tính số bình luận trung bình mỗi bài đăng
average_comments = comments_per_post.mean()
print(f"Số bình luận trung bình mỗi bài đăng: {average_comments}")

# %%
# Xác Định Nội Dung Tạo Ra Nhiều Tương Tác Nhất
engagement_by_content = df_c.groupby('Link').size().sort_values(ascending=False)

print(engagement_by_content)
